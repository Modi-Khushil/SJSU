# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushil-Modi/SJSU/blob/main/CMPE_257_Assignment_5_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Mounting-GDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###Importing Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
import time

names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

# %% [markdown]
# ###Data Loading

# %%
data = pd.read_csv("/content/drive/MyDrive/Datasets/ML-Dataset 2 Top Personality/2018-personality-data.csv")
data
# Out:
#                                 userid   openness   agreeableness  \
# 0     8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
# 1     77c7d756a093150d4377720abeaeef76        7.0             4.0
# 2     b7e8a92987a530cc368719a0e60e26a3        4.0             3.0
# 3     92561f21446e017dd6b68b94b23ad5b7        5.5             5.5
# 4     030001ac2145a938b07e686a35a2d638        5.5             5.5
# ...                                ...        ...             ...
# 1829  cff910b71f09b3120289ff6b461a9e03        5.5             3.5
# 1830  1ab3a4c2921d8da640854819b0f6cfce        4.0             3.5
# 1831  a06386edadf3bc614dadb7044708c46c        6.0             3.0
# 1832  bad56d9506832cd79d874a6b66b3d813        5.0             3.5
# 1833  721ea658e148fc0f76ddd6e2b0e02422        6.5             6.5
#
#        emotional_stability   conscientiousness   extraversion  \
# 0                      3.0                 2.5            6.5
# ...

# %% [markdown]
# ###Data Preprocessing

# %%
data[' agreeableness'] = round(((data[' agreeableness']*5)/7),1)
data[' openness'] = round(((data[' openness']*5)/7),1)
data[' emotional_stability'] = round(((data[' emotional_stability']*5)/7),1)
data[' conscientiousness'] = round(((data[' conscientiousness']*5)/7),1)
data[' extraversion'] = round(((data[' extraversion']*5)/7),1)
data
# Out:
#                                 userid   openness   agreeableness  \
# 0     8e7cebf9a234c064b75016249f2ac65e        3.6             1.4
# 1     77c7d756a093150d4377720abeaeef76        5.0             2.9
# 2     b7e8a92987a530cc368719a0e60e26a3        2.9             2.1
# 3     92561f21446e017dd6b68b94b23ad5b7        3.9             3.9
# 4     030001ac2145a938b07e686a35a2d638        3.9             3.9
# ...                                ...        ...             ...
# 1829  cff910b71f09b3120289ff6b461a9e03        3.9             2.5
# 1830  1ab3a4c2921d8da640854819b0f6cfce        2.9             2.5
# 1831  a06386edadf3bc614dadb7044708c46c        4.3             2.1
# 1832  bad56d9506832cd79d874a6b66b3d813        3.6             2.5
# 1833  721ea658e148fc0f76ddd6e2b0e02422        4.6             4.6
#
#        emotional_stability   conscientiousness   extraversion  \
# 0                      2.1                 1.8            4.6
# ...

# %%
data.drop(['userid', ' movie_1', ' movie_2', ' movie_3', ' movie_4', ' movie_5', ' movie_6', ' movie_7',
            ' movie_8', ' movie_9', ' movie_10', ' movie_11', ' movie_12', ' enjoy_watching '],axis=1,inplace=True)
data
# Out:
#        openness   agreeableness   emotional_stability   conscientiousness  \
# 0           3.6             1.4                   2.1                 1.8
# 1           5.0             2.9                   4.3                 3.9
# 2           2.9             2.1                   3.2                 1.4
# 3           3.9             3.9                   2.9                 3.2
# 4           3.9             3.9                   2.5                 3.2
# ...         ...             ...                   ...                 ...
# 1829        3.9             2.5                   1.8                 2.9
# 1830        2.9             2.5                   3.2                 2.9
# 1831        4.3             2.1                   3.9                 2.5
# 1832        3.6             2.5                   1.1                 2.5
# 1833        4.6             4.6                   1.8                 4.6
#
#        extraversion  assigned metric  assigned condition   predicted_rating_1  \
# ...

# %%
data.drop(data.loc[:, ' assigned metric':' is_personalized'].columns, axis=1, inplace=True)
data
# Out:
#        openness   agreeableness   emotional_stability   conscientiousness  \
# 0           3.6             1.4                   2.1                 1.8
# 1           5.0             2.9                   4.3                 3.9
# 2           2.9             2.1                   3.2                 1.4
# 3           3.9             3.9                   2.9                 3.2
# 4           3.9             3.9                   2.5                 3.2
# ...         ...             ...                   ...                 ...
# 1829        3.9             2.5                   1.8                 2.9
# 1830        2.9             2.5                   3.2                 2.9
# 1831        4.3             2.1                   3.9                 2.5
# 1832        3.6             2.5                   1.1                 2.5
# 1833        4.6             4.6                   1.8                 4.6
#
#        extraversion
# 0               4.6
# 1               2.9
# ...

# %%
Personality = (data[' agreeableness'] + data[' conscientiousness'] + data[' emotional_stability'] + data[' extraversion'] + data[' openness'])
data['Personality'] = Personality
data = pd.DataFrame(data)
data
# Out:
#        openness   agreeableness   emotional_stability   conscientiousness  \
# 0           3.6             1.4                   2.1                 1.8
# 1           5.0             2.9                   4.3                 3.9
# 2           2.9             2.1                   3.2                 1.4
# 3           3.9             3.9                   2.9                 3.2
# 4           3.9             3.9                   2.5                 3.2
# ...         ...             ...                   ...                 ...
# 1829        3.9             2.5                   1.8                 2.9
# 1830        2.9             2.5                   3.2                 2.9
# 1831        4.3             2.1                   3.9                 2.5
# 1832        3.6             2.5                   1.1                 2.5
# 1833        4.6             4.6                   1.8                 4.6
#
#        extraversion  Personality
# 0               4.6         13.5
# ...

# %%
a = data['Personality'].tolist()
b = [0] * len(a)
for i in range(0,1834):
  if a[i]<12.0:
    b[i]= "Bad" 
  elif a[i]>=12.0 and a[i]<17.0 :
    b[i] = "Medium" 
  else:
    b[i]= "Good"

data.head(5)
# Out:
#     openness   agreeableness   emotional_stability   conscientiousness  \
# 0        3.6             1.4                   2.1                 1.8
# 1        5.0             2.9                   4.3                 3.9
# 2        2.9             2.1                   3.2                 1.4
# 3        3.9             3.9                   2.9                 3.2
# 4        3.9             3.9                   2.5                 3.2
#
#     extraversion  Personality
# 0            4.6         13.5
# 1            2.9         19.0
# 2            1.8         11.4
# 3            2.9         16.8
# 4            1.8         15.3

# %%
d = pd.DataFrame(b)
d
# Out:
#            0
# 0     Medium
# 1       Good
# 2        Bad
# 3     Medium
# 4     Medium
# ...      ...
# 1829  Medium
# 1830  Medium
# 1831    Good
# 1832     Bad
# 1833    Good
#
# [1834 rows x 1 columns]

# %%
result = pd.concat([data, d], axis=1, join='inner')
result
# Out:
#        openness   agreeableness   emotional_stability   conscientiousness  \
# 0           3.6             1.4                   2.1                 1.8
# 1           5.0             2.9                   4.3                 3.9
# 2           2.9             2.1                   3.2                 1.4
# 3           3.9             3.9                   2.9                 3.2
# 4           3.9             3.9                   2.5                 3.2
# ...         ...             ...                   ...                 ...
# 1829        3.9             2.5                   1.8                 2.9
# 1830        2.9             2.5                   3.2                 2.9
# 1831        4.3             2.1                   3.9                 2.5
# 1832        3.6             2.5                   1.1                 2.5
# 1833        4.6             4.6                   1.8                 4.6
#
#        extraversion  Personality       0
# ...

# %%
result.set_axis([*result.columns[:-1], 'Test'], axis=1, inplace=True)

# %%
result.drop_duplicates(inplace=True)#Data Cleaning

# %%
result['Test'].value_counts()
# Out:
# Medium    1104
# Good       586
# Bad         88
# Name: Test, dtype: int64

# %%
le = preprocessing.LabelEncoder()
le.fit(result['Test'])
# Out:
# LabelEncoder()

# %%
result['Test'] = le.transform(result['Test'])
result
# Out:
#        openness   agreeableness   emotional_stability   conscientiousness  \
# 0           3.6             1.4                   2.1                 1.8
# 1           5.0             2.9                   4.3                 3.9
# 2           2.9             2.1                   3.2                 1.4
# 3           3.9             3.9                   2.9                 3.2
# 4           3.9             3.9                   2.5                 3.2
# ...         ...             ...                   ...                 ...
# 1829        3.9             2.5                   1.8                 2.9
# 1830        2.9             2.5                   3.2                 2.9
# 1831        4.3             2.1                   3.9                 2.5
# 1832        3.6             2.5                   1.1                 2.5
# 1833        4.6             4.6                   1.8                 4.6
#
#        extraversion  Personality  Test
# 0               4.6         13.5     2
# ...

# %% [markdown]
# ###Model Training & Data Testing

# %%
X = result.drop(['Test'], axis=1)
y = result['Test']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

# %%
classifiers = [
    DecisionTreeClassifier(max_depth=3,random_state=17),
    RandomForestClassifier(max_depth=3, random_state=17, n_estimators=10),
    KNeighborsClassifier(n_neighbors=3),
    MLPClassifier(random_state=17,learning_rate_init=0.01,max_iter=250),
    GaussianProcessClassifier(random_state=17)
]

# %%
max_score = 0.0
max_class = ''
# iterate over classifiers
for name, clf in zip(names, classifiers):
    start_time = time.time()
    clf.fit(X_train, y_train)
    score = 100.0 * clf.score(X_test, y_test)
    print('Classifier = %s, Score (test, accuracy) = %.2f,' %(name, score), 'Training time = %.2f seconds' % (time.time() - start_time))
    
    if score > max_score:
        clf_best = clf
        max_score = score
        max_class = name
# Out:
# Classifier = Nearest Neighbors, Score (test, accuracy) = 100.00, Training time = 0.01 seconds
# Classifier = Linear SVM, Score (test, accuracy) = 94.94, Training time = 0.02 seconds
# Classifier = RBF SVM, Score (test, accuracy) = 96.35, Training time = 0.02 seconds
# Classifier = Gaussian Process, Score (test, accuracy) = 98.03, Training time = 0.84 seconds
# Classifier = Decision Tree, Score (test, accuracy) = 98.31, Training time = 7.34 seconds

# %%
print('Best --> Classifier = %s, Score (test, accuracy) = %.2f' %(max_class, max_score))
# Out:
# Best --> Classifier = Nearest Neighbors, Score (test, accuracy) = 100.00

# %% [markdown]
# #Business Problem trying to Solve

# %% [markdown]
# ### Hereby we further try to describe any person's personality on the base of a total score of 5 different personalities and judging the people's ability into 3 parts namly, good, medium & bad, which descibes that how much well disciplined and flourished a person is as a human being. If they fell into good category they are the best people as ideal human beings and if in worst they needs to work a lot on themselves to become better humans. Similarly for medium category, where most of the people are, there is still more work to do and room to grow to become the ideal human beings.
